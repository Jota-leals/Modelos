# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import time

# %%
#API KEYS
bls_api = '476d935074304bb5921d6c11f03abcc3'
bea_api = '1877DB8B-6730-4F80-B187-242ACB99D57C'

# %%
#URLS

url_bea = "https://apps.bea.gov/api/data"
url_bls = "https://api.bls.gov/publicAPI/v2/timeseries/data/"

# %%
#Datos para demsempleo por Estado
estados = {
    "Alabama": "LAUST010000000000003",
    "Alaska": "LAUST020000000000003",
    "Arizona": "LAUST040000000000003",
    "Arkansas": "LAUST050000000000003",
    "California": "LAUST060000000000003",
    "Colorado": "LAUST080000000000003",
    "Connecticut": "LAUST090000000000003",
    "Delaware": "LAUST100000000000003",
    "Florida": "LAUST120000000000003",
    "Georgia": "LAUST130000000000003",
    "Hawaii": "LAUST150000000000003",
    "Idaho": "LAUST160000000000003",
    "Illinois": "LAUST170000000000003",
    "Indiana": "LAUST180000000000003",
    "Iowa": "LAUST190000000000003",
    "Kansas": "LAUST200000000000003",
    "Kentucky": "LAUST210000000000003",
    "Louisiana": "LAUST220000000000003",
    "Maine": "LAUST230000000000003",
    "Maryland": "LAUST240000000000003",
    "Massachusetts": "LAUST250000000000003",
    "Michigan": "LAUST260000000000003",
    "Minnesota": "LAUST270000000000003",
    "Mississippi": "LAUST280000000000003",
    "Missouri": "LAUST290000000000003",
    "Montana": "LAUST300000000000003",
    "Nebraska": "LAUST310000000000003",
    "Nevada": "LAUST320000000000003",
    "New Hampshire": "LAUST330000000000003",
    "New Jersey": "LAUST340000000000003",
    "New Mexico": "LAUST350000000000003",
    "New York": "LAUST360000000000003",
    "North Carolina": "LAUST370000000000003",
    "North Dakota": "LAUST380000000000003",
    "Ohio": "LAUST390000000000003",
    "Oklahoma": "LAUST400000000000003",
    "Oregon": "LAUST410000000000003",
    "Pennsylvania": "LAUST420000000000003",
    "Rhode Island": "LAUST440000000000003",
    "South Carolina": "LAUST450000000000003",
    "South Dakota": "LAUST460000000000003",
    "Tennessee": "LAUST470000000000003",
    "Texas": "LAUST480000000000003",
    "Utah": "LAUST490000000000003",
    "Vermont": "LAUST500000000000003",
    "Virginia": "LAUST510000000000003",
    "Washington": "LAUST530000000000003",
    "West Virginia": "LAUST540000000000003",
    "Wisconsin": "LAUST550000000000003",
    "Wyoming": "LAUST560000000000003"
}

# %%
meses = {
    "January": 1, "February": 2, "March": 3, "April": 4,
    "May": 5, "June": 6, "July": 7, "August": 8,
    "September": 9, "October": 10, "November": 11, "December": 12
}

# %%
rangos = [(2000, 2009), (2010, 2019), (2020, 2025)]

# %%
#Payload
registros = []

series = list(estados.values())

for start, end in rangos:
    for i in range(0, len(series), 25):  # La API solo acepta 25 series por consulta
        bloque = series[i:i+25]
        payload = {
            "seriesid": bloque,
            "startyear": str(start),
            "endyear": str(end)
        }
        url = "https://api.bls.gov/publicAPI/v2/timeseries/data/"
        response = requests.post(url, json=payload)
        data = response.json()

        # Procesar cada serie
        for serie in data["Results"]["series"]:
            estado = [k for k, v in estados.items() if v == serie["seriesID"]][0]
            for d in serie["data"]:
                if d["periodName"] in meses:
                    registros.append({
                        "Estado": estado,
                        "Año": int(d["year"]),
                        "Mes": meses[d["periodName"]],
                        "TasaDesempleo": float(d["value"])
                    })
        time.sleep(0.5)  # pequeño delay para no saturar la API

# %%
df = pd.DataFrame(registros)
df["Fecha"] = pd.to_datetime(df["Año"].astype(str) + "-" + df["Mes"].astype(str).str.zfill(2))
df = df.sort_values(["Estado", "Fecha"]).reset_index(drop=True)
df = df[df['Estado'] != 'New York city']
df = df[df['Estado'] != 'Los Angeles County']
df = df[['Estado','Fecha','TasaDesempleo']]
df['U_3m'] = df.groupby('Estado')['TasaDesempleo'].transform(lambda x: x.rolling(3, min_periods = 3).mean().round(2))
df['U_min12']= df.groupby('Estado')['U_3m'].transform(lambda x: x.rolling(12, min_periods = 12).min().round(2))
df['SahmRule'] = (df['U_3m']-df['U_min12']).round(2)
df['Dummy'] = (df['SahmRule'] >=0.5).astype(int)
df['Trim'] = df['Fecha'].dt.to_period('Q').astype(str)
df
# Out:
#         Estado      Fecha  TasaDesempleo  U_3m  U_min12  SahmRule  Dummy  \
# 0      Alabama 2000-01-01            5.1   NaN      NaN       NaN      0
# 1      Alabama 2000-02-01            5.1   NaN      NaN       NaN      0
# 2      Alabama 2000-03-01            4.7  4.97      NaN       NaN      0
# 3      Alabama 2000-04-01            4.1  4.63      NaN       NaN      0
# 4      Alabama 2000-05-01            4.3  4.37      NaN       NaN      0
# ...        ...        ...            ...   ...      ...       ...    ...
# 15395  Wyoming 2025-04-01            3.0  3.47     2.97      0.50      1
# 15396  Wyoming 2025-05-01            3.2  3.30     2.97      0.33      0
# 15397  Wyoming 2025-06-01            3.7  3.30     2.97      0.33      0
# 15398  Wyoming 2025-07-01            2.8  3.23     2.97      0.26      0
# 15399  Wyoming 2025-08-01            2.7  3.07     2.97      0.10      0
#
#          Trim
# 0      2000Q1
# 1      2000Q1
# 2      2000Q1
# 3      2000Q2
# 4      2000Q2
# ...       ...
# 15395  2025Q2
# 15396  2025Q2
# 15397  2025Q2
# 15398  2025Q3
# 15399  2025Q3
#
# [15400 rows x 8 columns]

# %%
#Parametros para GDP

params = {
    "UserID": bea_api,
    "method": "GetData",
    "datasetname": "Regional",
    "TableName": "SQGDP1",   
    "Frequency": "Q",
    "Year": "ALL",    
    'GeoFips':'STATE',     
    "ResultFormat": "JSON",
    'LineCode':1
}

# %%
#Request GDP
response = requests.get(url_bea, params=params)
response.status_code == 200
# Out:
# True

# %%
gdp = response.json()
gdp
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#      'ParameterValue': '1877DB8B-6730-4F80-B187-242ACB99D57C'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'REGIONAL'},
#     {'ParameterName': 'TABLENAME', 'ParameterValue': 'SQGDP1'},
#     {'ParameterName': 'FREQUENCY', 'ParameterValue': 'Q'},
#     {'ParameterName': 'YEAR', 'ParameterValue': 'ALL'},
#     {'ParameterName': 'GEOFIPS', 'ParameterValue': 'STATE'},
#     {'ParameterName': 'RESULTFORMAT', 'ParameterValue': 'JSON'},
#     {'ParameterName': 'LINECODE', 'ParameterValue': '1'}]},
#   'Results': {'Statistic': 'Real Gross Domestic Product (GDP)',
#    'UnitOfMeasure': 'Millions of chained 2017 dollars',
#    'PublicTable': 'SQGDP1 State quarterly gross domestic product (GDP) summary',
#    'UTCProductionTime': '2025-10-29T16:28:01.387',
#    'NoteRef': '1',
#    'Dimensions': [{'Name': 'Code', 'DataType': 'string', 'IsValue': '0'},
#     {'Name': 
3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '01000',
#      'GeoName': 'Alabama',
#      'TimePeriod': '2024Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '259006.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '01000',
#      'GeoName': 'Alabama',
#      'TimePeriod': '2025Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '258551.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '01000',
#      'GeoName': 'Alabama',
#      'TimePeriod': '2025Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '259350.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2005Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '44023.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2005Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '44542.3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2005Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '44267.3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2005Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '44793.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2006Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '45815.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2006Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '47205.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2006Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '47812.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2006Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '49351.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2007Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '49737.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2007Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '50520.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2007Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '50563.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2007Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '49684.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2008Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '48550.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2008Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '47477.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2008Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '49548.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2008Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '54130.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2009Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '56280.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2009Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '55535.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2009Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '54243.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2009Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '53748.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2010Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '52420.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2010Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '53799.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2010Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '54367.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2010Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '54020.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2011Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '52334.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2011Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '53339.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2011Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '54149.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2011Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '56358.6',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2012Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '56280.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2012Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '57869.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2012Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '57662.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2012Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '56537.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2013Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '56001.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '02000',
#      'GeoName': 'Alaska',
#      'TimePeriod': '2013Q2',
# ...
#      'GeoName': 'Georgia',
#      'TimePeriod': '2013Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '497941.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2013Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '500347.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2013Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '504163.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2014Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '507848.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2014Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '515854.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2014Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '521847.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2014Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '524496.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2015Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '532564.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2015Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '539696.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2015Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '542769.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2015Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '545402.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2016Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '556295.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2016Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '558761.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2016Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '563192.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2016Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '568623.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2017Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '576513.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2017Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '578985.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2017Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '584304.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2017Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '594370.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2018Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '592862.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2018Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '597845.3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2018Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '605171.3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2018Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '607859.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2019Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '611817.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2019Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '617858.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2019Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '625225.3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2019Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '628078.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2020Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '616257.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2020Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '567926.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2020Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '611620.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2020Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '617006.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2021Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '628848.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2021Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '638560.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2021Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '647200.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2021Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '660383.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2022Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '659210.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2022Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '669910.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2022Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '672371.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2022Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '678936.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2023Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '671964.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2023Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '676493.3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2023Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '682134.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2023Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '687196.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2024Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '690282.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2024Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '695600.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2024Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '699946.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2024Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '703974.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2025Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '702395.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '13000',
#      'GeoName': 'Georgia',
#      'TimePeriod': '2025Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '707272.9',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2005Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '71892.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2005Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '72515.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2005Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '73179.2',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2005Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '74181.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2006Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '73938.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2006Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '74759.7',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2006Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '75369.6',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2006Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '75504.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2007Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '75336.5',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2007Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '75761.1',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2007Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '76972.0',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2007Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '77666.8',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2008Q1',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '77352.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2008Q2',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '77990.4',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2008Q3',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '76898.3',
#      'NoteRef': '1'},
#     {'Code': 'SQGDP1-1',
#      'GeoFips': '15000',
#      'GeoName': 'Hawaii',
#      'TimePeriod': '2008Q4',
#      'CL_UNIT': 'Millions of chained 2017 dollars',
#      'UNIT_MULT': '6',
#      'DataValue': '75079.7',
#      'NoteRef': '1'},
#     ...],
#    'Notes': [{'NoteRef': '1',
#      'NoteText': 'Real GDP is in millions of chained 2017 dollars. Calculations are performed on unrounded data. Chained (2017) dollar series are calculated as the product of the chain-type quantity index and the 2017 current-dollar value of the corresponding series, divided by 100. Because the formula for the chain-type quantity indexes uses weights of more than one period, the corresponding chained-dollar estimates are usually not additive. For the All industry total and Government and government enterprises, the difference between the United States and sum-of-states reflects overseas activity, economic activity taking place outside the borders of the United States by the military and associated federal civilian support staff.'},
#     {'NoteRef': ' ',
#      'NoteText': 'Last updated: September 26, 2025-- new statistics for 2025:Q2; revised statistics for 2020:Q1-2025:Q1.'}]}}}

# %%
records = gdp['BEAAPI']['Results']['Data']
records
# Out:
# [{'Code': 'SQGDP1-1',
#   'GeoFips': '00000',
#   'GeoName': 'United States',
#   'TimePeriod': '2005Q1',
#   'CL_UNIT': 'Millions of chained 2017 dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '15844727.0',
#   'NoteRef': '1'},
#  {'Code': 'SQGDP1-1',
#   'GeoFips': '00000',
#   'GeoName': 'United States',
#   'TimePeriod': '2005Q2',
#   'CL_UNIT': 'Millions of chained 2017 dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '15922782.0',
#   'NoteRef': '1'},
#  {'Code': 'SQGDP1-1',
#   'GeoFips': '00000',
#   'GeoName': 'United States',
#   'TimePeriod': '2005Q3',
#   'CL_UNIT': 'Millions of chained 2017 dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '16047587.0',
#   'NoteRef': '1'},
#  {'Code': 'SQGDP1-1',
#   'GeoFips': '00000',
#   'GeoName': 'United States',
#   'TimePeriod': '2005Q4',
#   'CL_UNIT': 'Millions of chained 2017 dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '16136734.0',
#   'NoteRef': '1'},
#  {'Code': 'SQGDP1-1',
#   'GeoFips': '00000',
#   'GeoName': 'United States',
#   'TimePeriod': '2006Q1',
#   'CL_UNIT': 'Millions of chained 2017 dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '16353835.0',
#   'NoteRef': '1'},
#  {'Code': 'SQGDP1-1',
#   'GeoFips': '00000',
#   'GeoName': 'United States',
#   'TimePeriod': '2006Q2',
#   'CL_UNIT': 'Millions of chained 2017 dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '
# 4918       Far West     2025Q1   4674104.5
# 4919       Far West     2025Q2   4719587.8
#
# [4920 rows x 3 columns]

# %%
gdp_data["DataValue"] = pd.to_numeric(gdp_data["DataValue"], errors="coerce")
gdp_data.rename(columns={'GeoName':'Estado','TimePeriod':'Trim','DataValue':'GDP'}, inplace=True)
gdp_data
# Out:
#              Estado    Trim         GDP
# 0     United States  2005Q1  15844727.0
# 1     United States  2005Q2  15922782.0
# 2     United States  2005Q3  16047587.0
# 3     United States  2005Q4  16136734.0
# 4     United States  2006Q1  16353835.0
# ...             ...     ...         ...
# 4915       Far West  2024Q2   4606652.1
# 4916       Far West  2024Q3   4649588.3
# 4917       Far West  2024Q4   4679775.7
# 4918       Far West  2025Q1   4674104.5
# 4919       Far West  2025Q2   4719587.8
#
# [4920 rows x 3 columns]

# %%
base_cox = pd.merge(
    df,
    gdp_data[['Estado','Trim','GDP']],
    on=['Estado','Trim'],
    how='left'
)
base_cox
# Out:
#         Estado      Fecha  TasaDesempleo  U_3m  U_min12  SahmRule  Dummy  \
# 0      Alabama 2000-01-01            5.1   NaN      NaN       NaN      0
# 1      Alabama 2000-02-01            5.1   NaN      NaN       NaN      0
# 2      Alabama 2000-03-01            4.7  4.97      NaN       NaN      0
# 3      Alabama 2000-04-01            4.1  4.63      NaN       NaN      0
# 4      Alabama 2000-05-01            4.3  4.37      NaN       NaN      0
# ...        ...        ...            ...   ...      ...       ...    ...
# 15395  Wyoming 2025-04-01            3.0  3.47     2.97      0.50      1
# 15396  Wyoming 2025-05-01            3.2  3.30     2.97      0.33      0
# 15397  Wyoming 2025-06-01            3.7  3.30     2.97      0.33      0
# 15398  Wyoming 2025-07-01            2.8  3.23     2.97      0.26      0
# 15399  Wyoming 2025-08-01            2.7  3.07     2.97      0.10      0
#
#          Trim      GDP
# 0      2000Q1      NaN
# 1      2000Q1      NaN
# 2      2000Q1      NaN
# 3      2000Q2      NaN
# 4      2000Q2      NaN
# ...       ...      ...
# 15395  2025Q2  39982.7
# 15396  2025Q2  39982.7
# 15397  2025Q2  39982.7
# 15398  2025Q3      NaN
# 15399  2025Q3      NaN
#
# [15400 rows x 9 columns]

# %%
#Parametros Personla Income
params_pi = {
    "UserID": bea_api,
    "method": "GetData",
    "datasetname": "Regional",
    "TableName": "SQINC1",   
    "Frequency": "Q",
    "Year": "ALL",    
    'GeoFips':'STATE',     
    "ResultFormat": "JSON",
    'LineCode':1
}

# %%
#Request 
response_pi = requests.get(url_bea, params=params_pi)
response_pi.status_code == 200
# Out:
# True

# %%
pi = response_pi.json()
pi
# Out:
# {'BEAAPI': {'Request': {'RequestParam': [{'ParameterName': 'USERID',
#      'ParameterValue': '1877DB8B-6730-4F80-B187-242ACB99D57C'},
#     {'ParameterName': 'METHOD', 'ParameterValue': 'GETDATA'},
#     {'ParameterName': 'DATASETNAME', 'ParameterValue': 'REGIONAL'},
#     {'ParameterName': 'TABLENAME', 'ParameterValue': 'SQINC1'},
#     {'ParameterName': 'FREQUENCY', 'ParameterValue': 'Q'},
#     {'ParameterName': 'YEAR', 'ParameterValue': 'ALL'},
q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '48150.7',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2022Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '49641.9',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2022Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '50515.0',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2022Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '51145.2',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2022Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '51872.6',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2023Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '51822.5',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2023Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '53033.1',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2023Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '53918.5',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2023Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '54513.7',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2024Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '55420.6',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2024Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '56122.7',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2024Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '56762.7',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2024Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '57386.6',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2025Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '58725.0',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '02000',
#   'GeoName': 'Alaska *',
#   'TimePeriod': '2025Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '59439.8',
#   'NoteRef': '*'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1948Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '896.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1948Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '919.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1948Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '968.7'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1948Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '953.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1949Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '937.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1949Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '964.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1949Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '957.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1949Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '974.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1950Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1020.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1950Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1029.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1950Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1083.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1950Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1123.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1951Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1242.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1951Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1281.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1951Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1343.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1951Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1398.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1952Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1496.2'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1952Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1509.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1952Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1510.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1952Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1473.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1953Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1613.1'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1953Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1555.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1953Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1585.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1953Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1605.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1954Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1642.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1954Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1632.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1954Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1652.3'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1954Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1664.1'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1955Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1783.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1955Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1800.3'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1955Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1817.1'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1955Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1835.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1956Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '1983.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1956Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2016.2'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1956Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2060.7'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1956Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2097.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1957Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2196.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1957Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2225.3'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1957Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2252.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1957Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2254.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1958Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2257.2'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1958Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2337.1'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1958Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2388.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1958Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2506.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1959Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2537.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1959Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2614.2'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1959Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2614.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1959Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2707.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1960Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2781.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1960Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2843.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1960Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2884.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1960Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '2914.3'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1961Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3002.5'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1961Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3069.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1961Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3168.9'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1961Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3198.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1962Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3255.3'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1962Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3355.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1962Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3365.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1962Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3423.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1963Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3473.3'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1963Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3471.4'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1963Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3530.0'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1963Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3611.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1964Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3678.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1964Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3755.8'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1964Q3',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3803.3'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1964Q4',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3870.7'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1965Q1',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3918.6'},
#  {'Code': 'SQINC1-1',
#   'GeoFips': '04000',
#   'GeoName': 'Arizona',
#   'TimePeriod': '1965Q2',
#   'CL_UNIT': 'Millions of dollars',
#   'UNIT_MULT': '6',
#   'DataValue': '3958.9'},
#  ...]

# %%
data_pi = pd.DataFrame(records_pi)[['GeoName','TimePeriod','DataValue']]
data_pi
# Out:
#              GeoName TimePeriod  DataValue
# 0      United States     1971Q4   952246.9
# 1      United States     1972Q1   977447.2
# 2      United States     1972Q2   996338.5
# 3      United States     1972Q3  1023328.8
# 4      United States     1972Q4  1068517.5
# ...              ...        ...        ...
# 18595     Far West *     2024Q2  4739480.1
# 18596     Far West *     2024Q3  4788860.9
# 18597     Far West *     2024Q4  4876382.7
# 18598     Far West *     2025Q1  4932645.0
# 18599     Far West *     2025Q2  4992711.2
#
# [18600 rows x 3 columns]

# %%
data_pi['DataValue'] = pd.to_numeric(data_pi['DataValue'],errors='coerce')
data_pi.rename(columns={'GeoName':'Estado','TimePeriod':'Trim','DataValue':'Personal_Income'}, inplace=True)
data_pi["Estado"] = data_pi["Estado"].str.replace("*", "", regex=False).str.strip()
data_pi
# Out:
#               Estado    Trim  Personal_Income
# 0      United States  1971Q4         952246.9
# 1      United States  1972Q1         977447.2
# 2      United States  1972Q2         996338.5
# 3      United States  1972Q3        1023328.8
# 4      United States  1972Q4        1068517.5
# ...              ...     ...              ...
# 18595       Far West  2024Q2        4739480.1
# 18596       Far West  2024Q3        4788860.9
# 18597       Far West  2024Q4        4876382.7
# 18598       Far West  2025Q1        4932645.0
# 18599       Far West  2025Q2        4992711.2
#
# [18600 rows x 3 columns]

# %%
base_cox = pd.merge(
    base_cox,
    data_pi[['Estado','Trim','Personal_Income']],
    on=['Estado','Trim'],
    how='left'
)

# %%
base_cox
# Out:
#         Estado      Fecha  TasaDesempleo  U_3m  U_min12  SahmRule  Dummy  \
# 0      Alabama 2000-01-01            5.1   NaN      NaN       NaN      0
# 1      Alabama 2000-02-01            5.1   NaN      NaN       NaN      0
# 2      Alabama 2000-03-01            4.7  4.97      NaN       NaN      0
# 3      Alabama 2000-04-01            4.1  4.63      NaN       NaN      0
# 4      Alabama 2000-05-01            4.3  4.37      NaN       NaN      0
# ...        ...        ...            ...   ...      ...       ...    ...
# 15395  Wyoming 2025-04-01            3.0  3.47     2.97      0.50      1
# 15396  Wyoming 2025-05-01            3.2  3.30     2.97      0.33      0
# 15397  Wyoming 2025-06-01            3.7  3.30     2.97      0.33      0
# 15398  Wyoming 2025-07-01            2.8  3.23     2.97      0.26      0
# 15399  Wyoming 2025-08-01            2.7  3.07     2.97      0.10      0
#
#          Trim      GDP  Personal_Income
# 0      2000Q1      NaN         105965.0
# 1      2000Q1      NaN         105965.0
# 2      2000Q1      NaN         105965.0
# 3      2000Q2      NaN         107747.9
# 4      2000Q2      NaN         107747.9
# ...       ...      ...              ...
# 15395  2025Q2  39982.7          52880.9
# 15396  2025Q2  39982.7          52880.9
# 15397  2025Q2  39982.7          52880.9
# 15398  2025Q3      NaN              NaN
# 15399  2025Q3      NaN              NaN
#
# [15400 rows x 10 columns]

# %%
base_cox = base_cox[base_cox['Trim']>='2005-01-01']
base_cox = base_cox[base_cox['Trim']<'2015-01-01']
base_cox['GDP'] = np.log(base_cox['GDP'])
base_cox['Personal_Income']=np.log(base_cox['Personal_Income']) 
base_cox
# Out:
#         Estado      Fecha  TasaDesempleo  U_3m  U_min12  SahmRule  Dummy  \
# 60     Alabama 2005-01-01            5.4  5.13     5.07      0.06      0
# 61     Alabama 2005-02-01            5.4  5.23     5.07      0.16      0
# 62     Alabama 2005-03-01            4.6  5.13     5.07      0.06      0
# 63     Alabama 2005-04-01            4.1  4.70     4.70      0.00      0
# 64     Alabama 2005-05-01            4.0  4.23     4.23      0.00      0
# ...        ...        ...            ...   ...      ...       ...    ...
# 15267  Wyoming 2014-08-01            4.1  4.27     4.17      0.10      0
# 15268  Wyoming 2014-09-01            3.8  4.07     4.07      0.00      0
# 15269  Wyoming 2014-10-01            3.9  3.93     3.93      0.00      0
# 15270  Wyoming 2014-11-01            4.1  3.93     3.93      0.00      0
# 15271  Wyoming 2014-12-01            4.0  4.00     3.93      0.07      0
#
#          Trim        GDP  Personal_Income
# 60     2005Q1  12.184200        11.797564
# 61     2005Q1  12.184200        11.797564
# 62     2005Q1  12.184200        11.797564
# 63     2005Q2  12.193473        11.814656
# 64     2005Q2  12.193473        11.814656
# ...       ...        ...              ...
# 15267  2014Q3  10.585187        10.403726
# 15268  2014Q3  10.585187        10.403726
# 15269  2014Q4  10.602053        10.415817
# 15270  2014Q4  10.602053        10.415817
# 15271  2014Q4  10.602053        10.415817
#
# [6000 rows x 10 columns]
